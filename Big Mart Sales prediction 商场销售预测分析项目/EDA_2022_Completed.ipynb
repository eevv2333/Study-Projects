# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#Sales-Prediction-for-Big-Mart-Outlets" data-toc-modified-id="Sales-Prediction-for-Big-Mart-Outlets-0.0.1"><span class="toc-item-num">0.0.1&nbsp;&nbsp;</span>Sales Prediction for Big Mart Outlets</a></span></li><li><span><a href="#Hypothesis-Generation" data-toc-modified-id="Hypothesis-Generation-0.0.2"><span class="toc-item-num">0.0.2&nbsp;&nbsp;</span>Hypothesis Generation</a></span></li></ul></li><li><span><a href="#1）导入数据" data-toc-modified-id="1）导入数据-0.1"><span class="toc-item-num">0.1&nbsp;&nbsp;</span>1）导入数据</a></span></li><li><span><a href="#2）Understanding-the-Data" data-toc-modified-id="2）Understanding-the-Data-0.2"><span class="toc-item-num">0.2&nbsp;&nbsp;</span>2）Understanding the Data</a></span><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#2.1）合并两个表" data-toc-modified-id="2.1）合并两个表-0.2.0.1"><span class="toc-item-num">0.2.0.1&nbsp;&nbsp;</span>2.1）合并两个表</a></span></li></ul></li><li><span><a href="#2.2）Exploratory-Data-Analysis-(EDA）" data-toc-modified-id="2.2）Exploratory-Data-Analysis-(EDA）-0.2.1"><span class="toc-item-num">0.2.1&nbsp;&nbsp;</span>2.2）Exploratory Data Analysis (EDA）</a></span></li><li><span><a href="#univariate-Analysis-单变量分析" data-toc-modified-id="univariate-Analysis-单变量分析-0.2.2"><span class="toc-item-num">0.2.2&nbsp;&nbsp;</span><font color="Orange">univariate Analysis 单变量分析</font></a></span><ul class="toc-item"><li><span><a href="#a)-Target-Variable---Item_Outlet_Sales" data-toc-modified-id="a)-Target-Variable---Item_Outlet_Sales-0.2.2.1"><span class="toc-item-num">0.2.2.1&nbsp;&nbsp;</span><em>a) Target Variable - Item_Outlet_Sales</em></a></span></li><li><span><a href="#b)-Independent-Variables-(numeric-variables)" data-toc-modified-id="b)-Independent-Variables-(numeric-variables)-0.2.2.2"><span class="toc-item-num">0.2.2.2&nbsp;&nbsp;</span><em>b) Independent Variables (numeric variables)</em></a></span></li><li><span><a href="#Observation观察结论" data-toc-modified-id="Observation观察结论-0.2.2.3"><span class="toc-item-num">0.2.2.3&nbsp;&nbsp;</span><em>Observation</em>观察结论</a></span></li><li><span><a href="#c)-Independent-Variables-(categorical-variables)" data-toc-modified-id="c)-Independent-Variables-(categorical-variables)-0.2.2.4"><span class="toc-item-num">0.2.2.4&nbsp;&nbsp;</span><em>c) Independent Variables (categorical variables)</em></a></span></li><li><span><a href="#Problem发现问题" data-toc-modified-id="Problem发现问题-0.2.2.5"><span class="toc-item-num">0.2.2.5&nbsp;&nbsp;</span><em>Problem</em>发现问题</a></span></li><li><span><a href="#Observations观察结论" data-toc-modified-id="Observations观察结论-0.2.2.6"><span class="toc-item-num">0.2.2.6&nbsp;&nbsp;</span><em>Observations</em>观察结论</a></span></li></ul></li><li><span><a href="#Bivariate-Analysis-多变量分析" data-toc-modified-id="Bivariate-Analysis-多变量分析-0.2.3"><span class="toc-item-num">0.2.3&nbsp;&nbsp;</span><font color="Orange">Bivariate Analysis 多变量分析</font></a></span><ul class="toc-item"><li><span><a href="#a)-Target-Variable-vs-Independent-Numerical-Variables-目标变量和独立数值的关系" data-toc-modified-id="a)-Target-Variable-vs-Independent-Numerical-Variables-目标变量和独立数值的关系-0.2.3.1"><span class="toc-item-num">0.2.3.1&nbsp;&nbsp;</span>a) Target Variable vs Independent Numerical Variables 目标变量和独立数值的关系</a></span></li><li><span><a href="#Observations-发现问题" data-toc-modified-id="Observations-发现问题-0.2.3.2"><span class="toc-item-num">0.2.3.2&nbsp;&nbsp;</span>Observations 发现问题</a></span></li><li><span><a href="#Observations" data-toc-modified-id="Observations-0.2.3.3"><span class="toc-item-num">0.2.3.3&nbsp;&nbsp;</span>Observations</a></span></li><li><span><a href="#b)-Target-Variable-vs-Independent-Categorical-Variables" data-toc-modified-id="b)-Target-Variable-vs-Independent-Categorical-Variables-0.2.3.4"><span class="toc-item-num">0.2.3.4&nbsp;&nbsp;</span>b) Target Variable vs Independent Categorical Variables</a></span></li></ul></li><li><span><a href="#Observations" data-toc-modified-id="Observations-0.2.4"><span class="toc-item-num">0.2.4&nbsp;&nbsp;</span>Observations</a></span></li></ul></li><li><span><a href="#empty-values-in-Outlet_Size-variable.-Let’s-check-the-distribution-of-the-target-variable-across-Outlet_Size！" data-toc-modified-id="empty-values-in-Outlet_Size-variable.-Let’s-check-the-distribution-of-the-target-variable-across-Outlet_Size！-0.3"><span class="toc-item-num">0.3&nbsp;&nbsp;</span>empty values in Outlet_Size variable. Let’s check the distribution of the target variable across Outlet_Size！</a></span><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#Observations" data-toc-modified-id="Observations-0.3.0.1"><span class="toc-item-num">0.3.0.1&nbsp;&nbsp;</span>Observations</a></span></li></ul></li></ul></li><li><span><a href="#3）-Missing-Value-Treatment-缺失值处理" data-toc-modified-id="3）-Missing-Value-Treatment-缺失值处理-0.4"><span class="toc-item-num">0.4&nbsp;&nbsp;</span>3） Missing Value Treatment 缺失值处理</a></span><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#3.1）查缺失值" data-toc-modified-id="3.1）查缺失值-0.4.0.1"><span class="toc-item-num">0.4.0.1&nbsp;&nbsp;</span>3.1）查缺失值</a></span></li><li><span><a href="#3.2）处理缺失值" data-toc-modified-id="3.2）处理缺失值-0.4.0.2"><span class="toc-item-num">0.4.0.2&nbsp;&nbsp;</span>3.2）处理缺失值</a></span></li></ul></li></ul></li></ul></li><li><span><a href="#图画结果" data-toc-modified-id="图画结果-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>图画结果</a></span><ul class="toc-item"><li><span><a href="#4）Feature-Engineering-特征工程" data-toc-modified-id="4）Feature-Engineering-特征工程-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>4）Feature Engineering 特征工程</a></span><ul class="toc-item"><li><span><a href="#4.1）将多类别分成少数类-Item_Type_new" data-toc-modified-id="4.1）将多类别分成少数类-Item_Type_new-1.1.1"><span class="toc-item-num">1.1.1&nbsp;&nbsp;</span>4.1）将多类别分成少数类 Item_Type_new</a></span></li><li><span><a href="#4.2）提取一列数的前两位作为新特征-Item_category" data-toc-modified-id="4.2）提取一列数的前两位作为新特征-Item_category-1.1.2"><span class="toc-item-num">1.1.2&nbsp;&nbsp;</span>4.2）提取一列数的前两位作为新特征 Item_category</a></span></li><li><span><a href="#4.3）运算并创建新的特征-Outlet_Years和-price_per_unit_wt" data-toc-modified-id="4.3）运算并创建新的特征-Outlet_Years和-price_per_unit_wt-1.1.3"><span class="toc-item-num">1.1.3&nbsp;&nbsp;</span>4.3）运算并创建新的特征 Outlet_Years和 price_per_unit_wt</a></span></li><li><span><a href="#4.4)-根据数据大小，分组标签" data-toc-modified-id="4.4)-根据数据大小，分组标签-1.1.4"><span class="toc-item-num">1.1.4&nbsp;&nbsp;</span>4.4) 根据数据大小，分组标签</a></span><ul class="toc-item"><li><span><a href="#方法--用for-和if-语句" data-toc-modified-id="方法--用for-和if-语句-1.1.4.1"><span class="toc-item-num">1.1.4.1&nbsp;&nbsp;</span>方法- 用for 和if 语句</a></span></li></ul></li><li><span><a href="#4.5）查看结果" data-toc-modified-id="4.5）查看结果-1.1.5"><span class="toc-item-num">1.1.5&nbsp;&nbsp;</span>4.5）查看结果</a></span></li></ul></li><li><span><a href="#5）Encoding-Categorical-Variables" data-toc-modified-id="5）Encoding-Categorical-Variables-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>5）Encoding Categorical Variables</a></span><ul class="toc-item"><li><span><a href="#5.1）-Label-Encoding" data-toc-modified-id="5.1）-Label-Encoding-1.2.1"><span class="toc-item-num">1.2.1&nbsp;&nbsp;</span>5.1） Label Encoding</a></span></li></ul></li></ul></li><li><span><a href="#独热编码" data-toc-modified-id="独热编码-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>独热编码</a></span><ul class="toc-item"><li><span><a href="#数据预处理" data-toc-modified-id="数据预处理-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>数据预处理</a></span><ul class="toc-item"><li><span><a href="#Scaling-numeric-predictors：" data-toc-modified-id="Scaling-numeric-predictors：-2.1.1"><span class="toc-item-num">2.1.1&nbsp;&nbsp;</span>Scaling numeric predictors：</a></span></li><li><span><a href="#Splitting-the-combined-data-combi-back-to-train-and-test-set." data-toc-modified-id="Splitting-the-combined-data-combi-back-to-train-and-test-set.-2.1.2"><span class="toc-item-num">2.1.2&nbsp;&nbsp;</span>Splitting the combined data combi back to train and test set.</a></span></li></ul></li></ul></li><li><span><a href="#Model-Building" data-toc-modified-id="Model-Building-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Model Building</a></span><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#Evaluation-Metrics-for-Regression" data-toc-modified-id="Evaluation-Metrics-for-Regression-3.0.1"><span class="toc-item-num">3.0.1&nbsp;&nbsp;</span>Evaluation Metrics for Regression</a></span></li></ul></li></ul></li></ul></div>

# %% [markdown]
# ### Sales Prediction for Big Mart Outlets
#
# https://datahack.analyticsvidhya.com/contest/practice-problem-big-mart-sales-iii/#About
#
# - Exploratory Data Analysis
# - Data Preparation
# - Predictive Modeling using different techniques.

# %% [markdown]
# ### Hypothesis Generation
# 从店铺、产品、顾客、整体情况四个角度建立假设。
# - Store Level Hypotheses
# - Product Level Hypotheses
# - Customer Level Hypotheses
# - Macro Level Hypotheses

# %% [markdown]
# ## 1）导入数据

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
train=pd.read_csv('train_v9rqX0R (1).csv')
test=pd.read_csv('test_AbJTz2l.csv')

# %%
train.head(5)
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.000000
# 4           NCD19         8.93          Low Fat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# 2                       1999      Medium               Tier 1
# 3                       1998         NaN               Tier 3
# 4                       1987        High               Tier 3
#
#          Outlet_Type  Item_Outlet_Sales
# 0  Supermarket Type1          3735.1380
# 1  Supermarket Type2           443.4228
# 2  Supermarket Type1          2097.2700
# 3      Grocery Store           732.3800
# 4  Supermarket Type1           994.7052

# %%
# 查看数据特征
print(train.columns)
print(test.columns)
# Out:
# Index(['Item_Identifier', 'Item_Weight', 'Item_Fat_Content', 'Item_Visibility',
#        'Item_Type', 'Item_MRP', 'Outlet_Identifier',
#        'Outlet_Establishment_Year', 'Outlet_Size', 'Outlet_Location_Type',
#        'Outlet_Type', 'Item_Outlet_Sales'],
#       dtype='object')
# Index(['Item_Identifier', 'Item_Weight', 'Item_Fat_Content', 'Item_Visibility',
#        'Item_Type', 'Item_MRP', 'Outlet_Identifier',
#        'Outlet_Establishment_Year', 'Outlet_Size', 'Outlet_Location_Type',
#        'Outlet_Type'],
#       dtype='object')

# %% [markdown]
# test没有'Item_Outlet_Sales'一项

# %% [markdown]
# ## 2）Understanding the Data
# - Dimensions of Data == shape
# - Features of Data
# - Structure of Data: there are 4 numeric and 7 categorical variables.
# - Combine Train and Test <font color=Red> 是否需要合并两个样本？A：这里解释是先合并一起调整数据，之后有需要在分开。</font>

# %% [markdown]
# #### 2.1）合并两个表

# %%
## 合并两个报表 
Features=['Item_Identifier', 'Item_Weight', 'Item_Fat_Content', 'Item_Visibility',
       'Item_Type', 'Item_MRP', 'Outlet_Identifier',
       'Outlet_Establishment_Year', 'Outlet_Size', 'Outlet_Location_Type',
       'Outlet_Type']
combine=pd.merge(train,test,on=Features, how='outer')
print(combine.shape)
# Out:
# (14204, 12)

# %%
#查看数据类型
print(combine.dtypes)
# Out:
# Item_Identifier               object
# Item_Weight                  float64
# Item_Fat_Content              object
# Item_Visibility              float64
# Item_Type                     object
# Item_MRP                     float64
# Outlet_Identifier             object
# Outlet_Establishment_Year      int64
# Outlet_Size                   object
# Outlet_Location_Type          object
# Outlet_Type                   object
# Item_Outlet_Sales            float64
# dtype: object

# %% [markdown]
# 浮点类型(4)：
# 1. Item_Weight 物品重量
# 2. Item_Visibility 物品可见度
# 3. Item_MRP 物品MRP值
# 4. Item_Outlet_Sales 销售量
#
# 对象类型/类别(7)：
# 1. Item_Identifier
# 2. Item_Fat_Content
# 3. Item_Type
# 4. Outlet_Identifier
# 5. Outlet_Size
# 6. Outlet_Location_Type
# 7. Outlet_Type
#
# 数值类型：
# 1. Outlet_Establishment_Year      int64

# %% [markdown]
# ### 2.2）Exploratory Data Analysis (EDA）
#
# ###  <font color=Orange>univariate Analysis 单变量分析</font>
# 画出直方图观察数据情况
# ***
# #### *a) Target Variable - Item_Outlet_Sales*
# - Since our target variable is continuous, we can visualise it by plotting its histogram.
# 1. Item_Weight 物品重量
# 2. Item_Outlet_Sales 销售量

# %%
## train['Item_Outlet_Sales'].value_counts(normalize=True).plot.bar(title= 'Item_Outlet_Sales')太大了很久

# %%
plt.subplot(221)
sns.distplot(combine['Item_Outlet_Sales'])
plt.subplot(222)
sns.distplot(combine['Item_Weight'])

# %%
plt.figure(1)
plt.subplot(221)
sns.distplot(combine['Item_Outlet_Sales'])
plt.subplot(222)
sns.distplot(combine['Item_Weight'])
plt.subplot(223)
sns.distplot(combine['Item_Visibility'])
plt.subplot(224)
sns.distplot(combine['Item_MRP'])

# %% [markdown]
# #### *b) Independent Variables (numeric variables)*
# - Item_Visibility 物品可见度
# - Item_MRP 物品MRP值

# %%
plt.subplot(221)
sns.distplot(combine['Item_Visibility'])
plt.subplot(222)
sns.distplot(combine['Item_MRP'])

# %% [markdown]
# #### *Observation*观察结论
# - There seems to be no clear-cut pattern in Item_Weight.
# - Item_Visibility is right-skewed and should be transformed to curb its skewness.
# - We can clearly see 4 different distributions for Item_MRP. It is an interesting insight.

# %% [markdown]
# #### *c) Independent Variables (categorical variables)*
# - Item_Fat_Content‘ 脂肪含量

# %%
#画出直方图看数据情况
combine['Item_Fat_Content'].value_counts(normalize=True).plot.bar(figsize=(10,5), title= 'Item_Fat_Content')

# %% [markdown]
# #### *Problem*发现问题
# - 有重复的名字，只是分成两类
# - 需要替换名字

# %%
# ！！有重复的不同名字
combine['Item_Fat_Content'].replace('LF','Low Fat',inplace=True)
combine['Item_Fat_Content'].replace('low fat','Low Fat', inplace=True)
combine['Item_Fat_Content'].replace('reg','Regular',inplace=True)

#combine['Item_Fat_Content'].replace({'LF':'Low Fat','reg':'Regular','low fat':'Low Fat'},inplace=True)

# %%
#确认结果
combine['Item_Fat_Content'].value_counts(normalize=True).plot.bar(figsize=(10,5), title= 'Item_Fat_Content')

# %% [markdown]
# Fat content 没问题，继续看其他的几个特征

# %%
#观察四种特征情况
plt.figure(1)
combine['Outlet_Identifier'].value_counts(normalize=True).plot.bar(figsize=(10,2.5), title= 'Outlet_Identifier')

plt.figure(2)
plt.subplot(131)
combine['Outlet_Size'].value_counts(normalize=True).plot.bar(figsize=(10,2.5), title= 'Outlet_Size')
plt.subplot(132)
combine['Outlet_Location_Type'].value_counts(normalize=True).plot.bar(figsize=(10,2.5), title= 'Outlet_Location_Type')
plt.subplot(133)
combine['Outlet_Type'].value_counts(normalize=True).plot.bar(figsize=(10,2.5), title= 'Outlet_Type')

# %%
combine['Item_Type'].value_counts(normalize=True).plot.bar(figsize=(10,5), title= 'Item_Type')

# %%
# Outlet_Establishment_Year
combine['Outlet_Establishment_Year'].value_counts().plot.bar(figsize=(10,5), title= 'Outlet_Establishment_Year')

# %% [markdown]
# #### *Observations*观察结论
#
# - Lesser number of observations in the data for the outlets established in the year 1998 as compared to the other years.
# - Supermarket Type 1 seems to be the most popular category of Outlet_Type.

# %% [markdown]
# ### <font color=Orange>Bivariate Analysis 多变量分析</font>
# - scatter plots 用散点图观察变量之间的关系
# ***
# #### a) Target Variable vs Independent Numerical Variables 目标变量和独立数值的关系

# %%
#物品重量 和 销售量的相关性
plt.figure(1)
fig,ax=plt.subplots(figsize=(10,2))
ax.scatter(combine['Item_Weight'], combine['Item_Outlet_Sales'],color='pink')

#物品可见度 和 销售量的相关性
plt.figure(2)
fig,ax=plt.subplots(figsize=(10,2))
ax.scatter(combine['Item_Visibility'], combine['Item_Outlet_Sales'],color='pink')
#物品可见度 和 销售量的相关性

# tem_MRP 和销量相关性
plt.figure(3)
fig,ax=plt.subplots(figsize=(10,2))
ax.scatter(combine['Item_MRP'], combine['Item_Outlet_Sales'],color='pink')

# %% [markdown]
# #### Observations 发现问题
#
# - Item_Outlet_Sales is spread well across the entire range of the Item_Weight without any obvious pattern.
# - In Item_Visibility vs Item_Outlet_Sales, there is a string of points at Item_Visibility = 0.0 which seems strange as item visibility cannot be completely zero. We will take note of this issue and deal with it in the later stages.
# ***有一排数是Visibility=0.0,没有东西是彻底0的***

# %%
# tem_MRP 和销量相关性
fig,ax=plt.subplots(figsize=(10,5))
ax.scatter(combine['Item_MRP'], combine['Item_Outlet_Sales'],color='pink')

# %% [markdown]
# #### Observations
#
# - Item_Outlet_Sales is spread well across the entire range of the Item_Weight without any obvious pattern.
# - In Item_Visibility vs Item_Outlet_Sales, there is a string of points at Item_Visibility = 0.0 which seems strange as item visibility cannot be completely zero. We will take note of this issue and deal with it in the later stages.
# - In the third plot of Item_MRP vs Item_Outlet_Sales, we can clearly see 4 segments of prices that can be used in feature engineering to create a new variable.

# %% [markdown]
# #### b) Target Variable vs Independent Categorical Variables
#  - ***boxplots***
#  - ***violin plots***: The width of a violin plot at a particular level indicates the concentration or density of data at that level. The height of a violin tells us about the range of the target variable values.

# %%
#物品类别
import seaborn as sns
plt.figure(1)
fig,ax=plt.subplots(figsize=(20,8))
sns.set(style="whitegrid")
sns.boxenplot(x=combine['Item_Type'], y=combine['Item_Outlet_Sales'],scale="linear",color="yellow")

# %%
plt.figure(1)
fig,ax=plt.subplots(figsize=(20,8))
sns.violinplot(x=combine['Item_Type'], y=combine['Item_Outlet_Sales'])

# %%
#脂肪含量
sns.violinplot(x=combine['Item_Fat_Content'], y=combine['Item_Outlet_Sales'])

# %%
#商店编号
plt.figure(1)
fig,ax=plt.subplots(figsize=(10,3))
sns.violinplot(x=combine['Outlet_Identifier'], y=combine['Item_Outlet_Sales'])
plt.figure(2)
fig,ax=plt.subplots(figsize=(10,3))
sns.set(style="whitegrid")
sns.boxenplot(x=combine['Outlet_Identifier'], y=combine['Item_Outlet_Sales'],scale="linear",color="yellow")

# %% [markdown]
# ### Observations
# Distribution of Item_Outlet_Sales across the categories of Item_Type is not very distinct and same is the case with Item_Fat_Content. The distribution for OUT010 and OUT019 categories of Outlet_Identifier are quite similar and very much different from the rest of the categories of Outlet_Identifier.

# %%
#商店大小
sns.violinplot(x=combine['Outlet_Size'], y=combine['Item_Outlet_Sales'])

# %% [markdown]
# ## empty values in Outlet_Size variable. Let’s check the distribution of the target variable across Outlet_Size！
# ***教材说Size有空值，但是未显示***
# ![image.png](attachment:image.png)

# %%
#位置
sns.violinplot(x=combine['Outlet_Location_Type'], y=combine['Item_Outlet_Sales'])

# %%
sns.violinplot(x=combine['Outlet_Type'], y=combine['Item_Outlet_Sales'])

# %%
f,ax=plt.subplots(1,3,figsize=(18,3))
#商店大小
sns.violinplot(x=combine['Outlet_Size'], y=combine['Item_Outlet_Sales'],ax=ax[0])
#位置
sns.violinplot(x=combine['Outlet_Location_Type'],y=combine['Item_Outlet_Sales'],ax=ax[1])
#商店类型
sns.violinplot(x=combine['Outlet_Type'], y=combine['Item_Outlet_Sales'],ax=ax[2])

# %% [markdown]
# #### Observations
# - Tier 1 and Tier 3 locations of Outlet_Location_Type look similar.
# - In the Outlet_Type plot, Grocery Store has most of its data points around the lower sales values as compared to the other categories.

# %% [markdown]
# ## 3） Missing Value Treatment 缺失值处理
# 1. ***Deletion of rows***: In train dataset, observations having missing values in any variable are deleted. The downside of this method is the loss of information and drop in prediction power of model.
#
# 2. ***Mean/Median/Mode Imputation***: In case of continuous variable, missing values can be replaced with mean or median of all known values of that variable. For categorical variables, we can use mode of the given values to replace the missing values.
#
# 3. ***Building Prediction Model***: We can even make a predictive model to impute missing data in a variable. Here we will treat the variable having missing data as the target variable and the other variables as predictors. We will divide our data into 2 datasets—one without any missing value for that variable and the other with missing values for that variable. The former set would be used as training set to build the predictive model and it would then be applied to the latter set to predict the missing values.
#
# #### 3.1）查缺失值

# %%
print(combine.isnull().sum())
# Out:
# Item_Identifier                 0
# Item_Weight                  2439
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  4016
# Outlet_Location_Type            0
# Outlet_Type                     0
# Item_Outlet_Sales            5681
# dtype: int64

# %%
(combine['Item_Visibility'] == 0).value_counts()
# Out:
# False    13325
# True       879
# Name: Item_Visibility, dtype: int64

# %%
#原图
plt.figure(2)
plt.subplot(221)
sns.distplot(combine['Item_Weight'])
plt.subplot(222)
sns.distplot(combine['Item_Visibility'])

# %% [markdown]
# 一共两个数据是缺的
# - Item_Weight                  2439
# - Outlet_Size                  4016
# - Item_Visibility 有一排是0
#
# #### 3.2）处理缺失值
#
# - 第一步：根据Item_Identifier,计算出重量的均值

# %%
#利用数据透视表计算平均值 
pd.pivot_table(combine,index=['Item_Identifier'],values=['Item_Weight','Item_Visibility'],aggfunc=[np.mean])
# Out:
#                            mean
#                 Item_Visibility Item_Weight
# Item_Identifier
# DRA12                  0.034938      11.600
# DRA24                  0.045646      19.350
# DRA59                  0.133384       8.270
# DRB01                  0.079736       7.390
# DRB13                  0.006799       6.115
# ...                         ...         ...
# NCZ30                  0.027302       6.590
# NCZ41                  0.056396      19.850
# NCZ42                  0.011015      10.500
# NCZ53                  0.026330       9.600
# NCZ54                  0.081345      14.650
#
# [1559 rows x 2 columns]

# %% [markdown]
# - 第二步，根据物品类别，将各类的均值补充完整
# 根据Item_Identifier来确定平均值 。。。。

# %%
#combine['Item_Weight'] 最终解法输入¶
item_avg_weight = combine.pivot_table(values='Item_Weight', index='Item_Identifier') 
miss_bool = combine['Item_Weight'].isnull() 
combine.loc[miss_bool,'Item_Weight'] = combine.loc[miss_bool,'Item_Identifier'].apply(lambda x: item_avg_weight.loc[x])

# %%
#replace Replacing 0’s in Item_Visibility variable
visibility_avg = combine.pivot_table(index='Item_Identifier', values='Item_Visibility')
miss_bool = (combine['Item_Visibility'] == 0)  #这里是要替代0值，不是空值。
combine.loc[miss_bool,'Item_Visibility'] = combine.loc[miss_bool,'Item_Identifier'].apply(lambda x: visibility_avg.loc[x])

# %%
# Size

# %%
#查看10个商店的类型
pd.crosstab(combine.Outlet_Identifier,combine.Outlet_Size).T.style.background_gradient(cmap='summer_r')
# Out:
# <style  type="text/css" >
#     #T_f235ba74_ef72_11ea_b772_6476baa61d9crow0_col0 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_f235ba74_ef72_11ea_b772_6476baa61d9crow0_col1 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_f235ba74_ef72_11ea_b772_6476baa61d9crow0_col2 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_f235ba74_ef72_11ea_b772_6476baa61d9crow0_col3 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_f235ba74_ef72_11ea_b772_6476baa61d9crow0_col4 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_f235ba74_ef72_11ea_b772_6476baa61d9crow0_col5 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_f235ba74_ef72_11ea_b772_6476baa61d9crow0_col6 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_f235ba74_ef72_11ea_b772_6476baa61d9crow1_col0 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_f235ba74_ef72_11ea_b772_6476baa61d9crow1_col1 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_f235ba74_ef72_11ea_b772_6476baa61d9crow1_col2 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_f235ba74_ef72_11ea_b772_6476baa61d9crow1_col3 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_f235ba74_ef72_11ea_b772_6476baa61d9crow1_col4 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_f235ba74_ef72_11ea_b772_6476baa61d9crow1_col5 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_f235ba74_ef72_11ea_b772_6476baa61d9crow1_col6 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_f235ba74_ef72_11ea_b772_6476baa61d9crow2_col0 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_f235ba74_ef72_11ea_b772_6476baa61d9crow2_col1 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_f235ba74_ef72_11ea_b772_6476baa61d9crow2_col2 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_f235ba74_ef72_11ea_b772_6476baa61d9crow2_col3 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_f235ba74_ef72_11ea_b772_6476baa61d9crow2_col4 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_f235ba74_ef72_11ea_b772_6476baa61d9crow2_col5 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_f235ba74_ef72_11ea_b772_6476baa61d9crow2_col6 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }</style><table id="T_f235ba74_ef72_11ea_b772_6476baa61d9c" ><thead>    <tr>        <th class="index_name level0" >Outlet_Identifier</th>        <th class="col_heading level0 col0" >OUT013</th>        <th class="col_heading level0 col1" >OUT018</th>        <th class="col_heading level0 col2" >OUT019</th>        <th class="col_heading level0 col3" >OUT027</th>        <th class="col_heading level0 col4" >OUT035</th>        <th class="col_heading level0 col5" >OUT046</th>        <th class="col_heading level0 col6" >OUT049</th>    </tr>    <tr>        <th class="index_name level0" >Outlet_Size</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_f235ba74_ef72_11ea_b772_6476baa61d9clevel0_row0" class="row_heading level0 row0" >High</th>
#                         <td id="T_f235ba74_ef72_11ea_b772_6476baa61d9crow0_col0" class="data row0 col0" >1553</td>
#                         <td id="T_f235ba74_ef72_11ea_b772_6476baa61d9crow0_col1" class="data row0 col1" >0</td>
#                         <td id="T_f235ba74_ef72_11ea_b772_6476baa61d9crow0_col2" class="data row0 col2" >0</td>
#                         <td id="T_f235ba74_ef72_11ea_b772_6476baa61d9crow0_col3" class="data row0 col3" >0</td>
#                         <td id="T_f235ba74_ef72_11ea_b772_6476baa61d9crow0_col4" class="data row0 col4" >0</td>
#                         <td id="T_f235ba74_ef72_11ea_b772_6476baa61d9crow0_col5" class="data row0 col5" >0</td>
#                         <td id="T_f235ba74_ef72_11ea_b772_6476baa61d9crow0_col6" class="data row0 col6" >0</td>
#             </tr>
#             <tr>
#                         <th id="T_f235ba74_ef72_11ea_b772_6476baa61d9clevel0_row1" class="row_heading level0 row1" >Medium</th>
#                         <td id="T_f235ba74_ef72_11ea_b772_6476baa61d9crow1_col0" class="data row1 col0" >0</td>
#                         <td id="T_f235ba74_ef72_11ea_b772_6476baa61d9crow1_col1" class="data row1 col1" >1546</td>
#                         <td id="T_f235ba74_ef72_11ea_b772_6476baa61d9crow1_col2" class="data row1 col2" >0</td>
#                         <td id="T_f235ba74_ef72_11ea_b772_6476baa61d9crow1_col3" class="data row1 col3" >1559</td>
#                         <td id="T_f235ba74_ef72_11ea_b772_6476baa61d9crow1_col4" class="data row1 col4" >0</td>
#                         <td id="T_f235ba74_ef72_11ea_b772_6476baa61d9crow1_col5" class="data row1 col5" >0</td>
#                         <td id="T_f235ba74_ef72_11ea_b772_6476baa61d9crow1_col6" class="data row1 col6" >1550</td>
#             </tr>
#             <tr>
#                         <th id="T_f235ba74_ef72_11ea_b772_6476baa61d9clevel0_row2" class="row_heading level0 row2" >Small</th>
#                         <td id="T_f235ba74_ef72_11ea_b772_6476baa61d9crow2_col0" class="data row2 col0" >0</td>
#                         <td id="T_f235ba74_ef72_11ea_b772_6476baa61d9crow2_col1" class="data row2 col1" >0</td>
#                         <td id="T_f235ba74_ef72_11ea_b772_6476baa61d9crow2_col2" class="data row2 col2" >880</td>
#                         <td id="T_f235ba74_ef72_11ea_b772_6476baa61d9crow2_col3" class="data row2 col3" >0</td>
#                         <td id="T_f235ba74_ef72_11ea_b772_6476baa61d9crow2_col4" class="data row2 col4" >1550</td>
#                         <td id="T_f235ba74_ef72_11ea_b772_6476baa61d9crow2_col5" class="data row2 col5" >1550</td>
#                         <td id="T_f235ba74_ef72_11ea_b772_6476baa61d9crow2_col6" class="data row2 col6" >0</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# 缺少3个值， 不能用编号，使用类型划分

# %%
#查看大小和类型的关系
pd.crosstab(combine.Outlet_Identifier,[combine.Outlet_Type,combine.Outlet_Size]).T.style.background_gradient(cmap='summer_r')
# Out:
# <style  type="text/css" >
#     #T_f24c8a56_ef72_11ea_b772_6476baa61d9crow0_col0 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_f24c8a56_ef72_11ea_b772_6476baa61d9crow0_col1 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_f24c8a56_ef72_11ea_b772_6476baa61d9crow0_col2 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_f24c8a56_ef72_11ea_b772_6476baa61d9crow0_col3 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_f24c8a56_ef72_11ea_b772_6476baa61d9crow0_col4 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_f24c8a56_ef72_11ea_b772_6476baa61d9crow0_col5 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_f24c8a56_ef72_11ea_b772_6476baa61d9crow0_col6 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_f24c8a56_ef72_11ea_b772_6476baa61d9crow1_col0 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_f24c8a56_ef72_11ea_b772_6476baa61d9crow1_col1 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_f24c8a56_ef72_11ea_b772_6476baa61d9crow1_col2 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_f24c8a56_ef72_11ea_b772_6476baa61d9crow1_col3 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_f24c8a56_ef72_11ea_b772_6476baa61d9crow1_col4 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_f24c8a56_ef72_11ea_b772_6476baa61d9crow1_col5 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_f24c8a56_ef72_11ea_b772_6476baa61d9crow1_col6 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_f24c8a56_ef72_11ea_b772_6476baa61d9crow2_col0 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_f24c8a56_ef72_11ea_b772_6476baa61d9crow2_col1 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_f24c8a56_ef72_11ea_b772_6476baa61d9crow2_col2 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_f24c8a56_ef72_11ea_b772_6476baa61d9crow2_col3 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_f24c8a56_ef72_11ea_b772_6476baa61d9crow2_col4 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_f24c8a56_ef72_11ea_b772_6476baa61d9crow2_col5 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_f24c8a56_ef72_11ea_b772_6476baa61d9crow2_col6 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_f24c8a56_ef72_11ea_b772_6476baa61d9crow3_col0 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_f24c8a56_ef72_11ea_b772_6476baa61d9crow3_col1 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_f24c8a56_ef72_11ea_b772_6476baa61d9crow3_col2 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_f24c8a56_ef72_11ea_b772_6476baa61d9crow3_col3 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_f24c8a56_ef72_11ea_b772_6476baa61d9crow3_col4 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_f24c8a56_ef72_11ea_b772_6476baa61d9crow3_col5 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_f24c8a56_ef72_11ea_b772_6476baa61d9crow3_col6 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_f24c8a56_ef72_11ea_b772_6476baa61d9crow4_col0 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_f24c8a56_ef72_11ea_b772_6476baa61d9crow4_col1 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_f24c8a56_ef72_11ea_b772_6476baa61d9crow4_col2 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_f24c8a56_ef72_11ea_b772_6476baa61d9crow4_col3 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_f24c8a56_ef72_11ea_b772_6476baa61d9crow4_col4 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_f24c8a56_ef72_11ea_b772_6476baa61d9crow4_col5 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_f24c8a56_ef72_11ea_b772_6476baa61d9crow4_col6 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_f24c8a56_ef72_11ea_b772_6476baa61d9crow5_col0 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_f24c8a56_ef72_11ea_b772_6476baa61d9crow5_col1 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_f24c8a56_ef72_11ea_b772_6476baa61d9crow5_col2 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_f24c8a56_ef72_11ea_b772_6476baa61d9crow5_col3 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_f24c8a56_ef72_11ea_b772_6476baa61d9crow5_col4 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_f24c8a56_ef72_11ea_b772_6476baa61d9crow5_col5 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_f24c8a56_ef72_11ea_b772_6476baa61d9crow5_col6 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }</style><table id="T_f24c8a56_ef72_11ea_b772_6476baa61d9c" ><thead>    <tr>        <th class="blank" ></th>        <th class="index_name level0" >Outlet_Identifier</th>        <th class="col_heading level0 col0" >OUT013</th>        <th class="col_heading level0 col1" >OUT018</th>        <th class="col_heading level0 col2" >OUT019</th>        <th class="col_heading level0 col3" >OUT027</th>        <th class="col_heading level0 col4" >OUT035</th>        <th class="col_heading level0 col5" >OUT046</th>        <th class="col_heading level0 col6" >OUT049</th>    </tr>    <tr>        <th class="index_name level0" >Outlet_Type</th>        <th class="index_name level1" >Outlet_Size</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_f24c8a56_ef72_11ea_b772_6476baa61d9clevel0_row0" class="row_heading level0 row0" >Grocery Store</th>
#                         <th id="T_f24c8a56_ef72_11ea_b772_6476baa61d9clevel1_row0" class="row_heading level1 row0" >Small</th>
#                         <td id="T_f24c8a56_ef72_11ea_b772_6476baa61d9crow0_col0" class="data row0 col0" >0</td>
#                         <td id="T_f24c8a56_ef72_11ea_b772_6476baa61d9crow0_col1" class="data row0 col1" >0</td>
#                         <td id="T_f24c8a56_ef72_11ea_b772_6476baa61d9crow0_col2" class="data row0 col2" >880</td>
#                         <td id="T_f24c8a56_ef72_11ea_b772_6476baa61d9crow0_col3" class="data row0 col3" >0</td>
#                         <td id="T_f24c8a56_ef72_11ea_b772_6476baa61d9crow0_col4" class="data row0 col4" >0</td>
#                         <td id="T_f24c8a56_ef72_11ea_b772_6476baa61d9crow0_col5" class="data row0 col5" >0</td>
#                         <td id="T_f24c8a56_ef72_11ea_b772_6476baa61d9crow0_col6" class="data row0 col6" >0</td>
#             </tr>
#             <tr>
#                         <th id="T_f24c8a56_ef72_11ea_b772_6476baa61d9clevel0_row1" class="row_heading level0 row1" rowspan=3>Supermarket Type1</th>
#                         <th id="T_f24c8a56_ef72_11ea_b772_6476baa61d9clevel1_row1" class="row_heading level1 row1" >High</th>
#                         <td id="T_f24c8a56_ef72_11ea_b772_6476baa61d9crow1

# %% [markdown]
# - Grocery Store： small
# - Supermarket Type1: 最多是SMall
# - Supermarket Type2 和 Type3 都是Medium

# %%
#查看10个商店的类型
pd.crosstab(combine.Outlet_Identifier,combine.Outlet_Type).T.style.background_gradient(cmap='summer_r')
# Out:
# <style  type="text/css" >
#     #T_f2574b44_ef72_11ea_b772_6476baa61d9crow0_col0 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_f2574b44_ef72_11ea_b772_6476baa61d9crow0_col1 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_f2574b44_ef72_11ea_b772_6476baa61d9crow0_col2 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_f2574b44_ef72_11ea_b772_6476baa61d9crow0_col3 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_f2574b44_ef72_11ea_b772_6476baa61d9crow0_col4 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_f2574b44_ef72_11ea_b772_6476baa61d9crow0_col5 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_f2574b44_ef72_11ea_b772_6476baa61d9crow0_col6 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_f2574b44_ef72_11ea_b772_6476baa61d9crow0_col7 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_f2574b44_ef72_11ea_b772_6476baa61d9crow0_col8 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_f2574b44_ef72_11ea_b772_6476baa61d9crow0_col9 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_f2574b44_ef72_11ea_b772_6476baa61d9crow1_col0 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_f2574b44_ef72_11ea_b772_6476baa61d9crow1_col1 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_f2574b44_ef72_11ea_b772_6476baa61d9crow1_col2 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_f2574b44_ef72_11ea_b772_6476baa61d9crow1_col3 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_f2574b44_ef72_11ea_b772_6476baa61d9crow1_col4 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_f2574b44_ef72_11ea_b772_6476baa61d9crow1_col5 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_f2574b44_ef72_11ea_b772_6476baa61d9crow1_col6 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_f2574b44_ef72_11ea_b772_6476baa61d9crow1_col7 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_f2574b44_ef72_11ea_b772_6476baa61d9crow1_col8 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_f2574b44_ef72_11ea_b772_6476baa61d9crow1_col9 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_f2574b44_ef72_11ea_b772_6476baa61d9crow2_col0 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_f2574b44_ef72_11ea_b772_6476baa61d9crow2_col1 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_f2574b44_ef72_11ea_b772_6476baa61d9crow2_col2 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_f2574b44_ef72_11ea_b772_6476baa61d9crow2_col3 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_f2574b44_ef72_11ea_b772_6476baa61d9crow2_col4 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_f2574b44_ef72_11ea_b772_6476baa61d9crow2_col5 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_f2574b44_ef72_11ea_b772_6476baa61d9crow2_col6 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_f2574b44_ef72_11ea_b772_6476baa61d9crow2_col7 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_f2574b44_ef72_11ea_b772_6476baa61d9crow2_col8 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_f2574b44_ef72_11ea_b772_6476baa61d9crow2_col9 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_f2574b44_ef72_11ea_b772_6476baa61d9crow3_col0 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_f2574b44_ef72_11ea_b772_6476baa61d9crow3_col1 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_f2574b44_ef72_11ea_b772_6476baa61d9crow3_col2 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_f2574b44_ef72_11ea_b772_6476baa61d9crow3_col3 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_f2574b44_ef72_11ea_b772_6476baa61d9crow3_col4 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_f2574b44_ef72_11ea_b772_6476baa61d9crow3_col5 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_f2574b44_ef72_11ea_b772_6476baa61d9crow3_col6 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_f2574b44_ef72_11ea_b772_6476baa61d9crow3_col7 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_f2574b44_ef72_11ea_b772_6476baa61d9crow3_col8 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_f2574b44_ef72_11ea_b772_6476baa61d9crow3_col9 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }</style><table id="T_f2574b44_ef72_11ea_b772_6476baa61d9c" ><thead>    <tr>        <th class="index_name level0" >Outlet_Identifier</th>        <th class="col_heading level0 col0" >OUT010</th>        <th class="col_heading level0 col1" >OUT013</th>        <th class="col_heading level0 col2" >OUT017</th>        <th class="col_heading level0 col3" >OUT018</th>        <th class="col_heading level0 col4" >OUT019</th>        <th class="col_heading level0 col5" >OUT027</th>        <th class="col_heading level0 col6" >OUT035</th>        <th class="col_heading level0 col7" >OUT045</th>        <th class="col_heading level0 col8" >OUT046</th>        <th class="col_heading level0 col9" >OUT049</th>    </tr>    <tr>        <th class="index_name level0" >Outlet_Type</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_f2574b44_ef72_11ea_b772_6476baa61d9clevel0_row0" class="row_heading level0 row0" >Grocery Store</th>
#                         <td id="T_f2574b44_ef72_11ea_b772_6476baa61d9crow0_col0" class="data row0 col0" >925</td>
#                         <td id="T_f2574b44_ef72_11ea_b772_6476baa61d9crow0_col1" class="data row0 col1" >0</td>
#                         <td id="T_f2574b44_ef72_11ea_b772_6476baa61d9crow0_col2" class="data row0 col2" >0</td>
#                         <td id="T_f2574b44_ef72_11ea_b772_6476baa61d9crow0_col3" class="data row0 col3" >0</td>
#                         <td id="T_f2574b44_ef72_11ea_b772_6476baa61d9crow0_col4" class="data row0 col4" >880</td>
#                         <td id="T_f2574b44_ef72_11ea_b772_6476baa61d9crow0_col5" class="data row0 col5" >0</td>
#                         <td id="T_f2574b44_ef72_11ea_b772_6476baa61d9crow0_col6" class="data row0 col6" >0</td>
#                         <td id="T_f2574b44_ef72_11ea_b772_6476baa61d9crow0_col7" class="data row0 col7" >0</td>
#                         <td id="T_f2574b44_ef72_11ea_b772_6476baa61d9crow0_col8" class="data row0 col8" >0</td>
#                         <td id="T_f2574b44_ef72_11ea_b772_6476baa61d9crow0_col9" class="data row0 col9" >0</td>
#             </tr>
#             <tr>
#                         <th id="T_f2574b44_ef72_11ea_b772_6476baa61d9clevel0_row1" class="row_heading level0 row1" >Supermarket Type1</th>
#                         <td id="T_f2574b44_ef72_11ea_b772_6476baa61d9crow1_col0" class=

# %%
## 替换方法
combine.loc[(combine.Outlet_Size.isnull())&(combine.Outlet_Identifier=='OUT010'),'Outlet_Size']='Small'
combine.loc[(combine.Outlet_Size.isnull())&(combine.Outlet_Identifier=='OUT017'),'Outlet_Size']='Small'
combine.loc[(combine.Outlet_Size.isnull())&(combine.Outlet_Identifier=='OUT045'),'Outlet_Size']='Small'

# %%
### 废弃方法
#不可以直接用，有个缺失值的。
'''
#Size
from scipy.stats import mode
outlet_size_mode = combine.pivot_table(values='Outlet_Size', index='Outlet_Type',aggfunc=(lambda x:mode(x.astype(str)).mode[0]) )
miss_bool = combine['Outlet_Size'].isnull() 
combine.loc[miss_bool,'Outlet_Size'] = combine.loc[miss_bool,'Outlet_Type'].apply(lambda x: outlet_size_mode.loc[x])
outlet_size_mode
'''
# Out:
# "\n#Size\nfrom scipy.stats import mode\noutlet_size_mode = combine.pivot_table(values='Outlet_Size', index='Outlet_Type',aggfunc=(lambda x:mode(x.astype(str)).mode[0]) )\nmiss_bool = combine['Outlet_Size'].isnull() \ncombine.loc[miss_bool,'Outlet_Size'] = combine.loc[miss_bool,'Outlet_Type'].apply(lambda x: outlet_size_mode.loc[x])\noutlet_size_mode\n"

# %%
#检查
print(combine.isnull().sum())
# Out:
# Item_Identifier                 0
# Item_Weight                     0
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                     0
# Outlet_Location_Type            0
# Outlet_Type                     0
# Item_Outlet_Sales            5681
# dtype: int64

# %% [markdown]
# # 图画结果

# %%
combine.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.017834
# 4           NCD19         8.93          Low Fat         0.009780
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# 2                       1999      Medium               Tier 1
# 3                       1998       Small               Tier 3
# 4                       1987        High               Tier 3
#
#          Outlet_Type  Item_Outlet_Sales
# 0  Supermarket Type1          3735.1380
# 1  Supermarket Type2           443.4228
# 2  Supermarket Type1          2097.2700
# 3      Grocery Store           732.3800
# 4  Supermarket Type1           994.7052

# %% [markdown]
# ## 4）Feature Engineering 特征工程
# Most of the times, the given features in a dataset are not sufficient to give satisfactory predictions. In such cases, we have to create new features which might help in improving the model’s performance. Let’s try to create some new features for our dataset.
#
# In this section we will create the following new features:
#
# - Item_Type_new: Broader categories for the variable Item_Type.
# - Item_category: Categorical variable derived from Item_Identifier.
# - Outlet_Years: Years of operation for outlets.
# - price_per_unit_wt: Item_MRP/Item_Weight
# - Item_MRP_clusters: Binned feature for Item_MRP.
#
# 现有的特征效果不佳，可以创建新的特征来提高模型
#
# We can have a look at the Item_Type variable and classify the categories into perishable and non_perishable as per our understanding and make it into a new feature.
# 将物品分成perishable and non_perishable两种
#
# Let’s compare Item_Type with the first 2 characters of Item_Identifier, i.e., ‘DR’, ‘FD’, and ‘NC’. These identifiers most probably stand for drinks, food, and non-consumable.
# Item_Identifier 的头两个字母分别是‘DR’, ‘FD’, and ‘NC’，即饮料、食物和消费品。

# %% [markdown]
# ### 4.1）将多类别分成少数类 Item_Type_new

# %%
perishable = ["Breads", "Breakfast", "Dairy", "Fruits and Vegetables", "Meat", "Seafood"]
non_perishable = ["Baking Goods", "Canned", "Frozen Foods", "Hard Drinks", "Health and Hygiene", "Household", "Soft Drinks"]

# %%
newtype=[]
for z in range(0,len(combine['Item_Type'])):
    z = combine['Item_Type'][z]
    if z in perishable:
        newtype.append("perishable") 
    else:
        newtype.append("non_perishable")

# %%
combine['Item_Type_new']=newtype

# %% [markdown]
# ### 4.2）提取一列数的前两位作为新特征 Item_category

# %%
## 取Item_Identifier的前两位作为新特征
combine['Item_category']=[x[:2] for x in combine['Item_Identifier']]

# %%
combine["Item_category"].value_counts()
# Out:
# FD    10201
# NC     2686
# DR     1317
# Name: Item_category, dtype: int64

# %%
##查看每类具体有什么类型商品
pd.pivot_table(combine,index=["Item_Type"],values=["Item_Identifier"],columns=["Item_category"],aggfunc='count').T
# Out:
# Item_Type                      Baking Goods  Breads  Breakfast  Canned  Dairy  \
#                 Item_category
# Item_Identifier DR                      NaN     NaN        NaN     NaN  229.0
#                 FD                   1086.0   416.0      186.0  1084.0  907.0
#                 NC                      NaN     NaN        NaN     NaN    NaN
#
# Item_Type                      Frozen Foods  Fruits and Vegetables  \
#                 Item_category
# Item_Identifier DR                      NaN                    NaN
#                 FD                   1426.0                 2013.0
#                 NC                      NaN                    NaN
#
# Item_Type                      Hard Drinks  Health and Hygiene  Household  \
#                 Item_category
# Item_Identifier DR                   362.0                 NaN        NaN
#                 FD                     NaN                 NaN        NaN
#                 NC                     NaN               858.0     1548.0
#
# Item_Type                       Meat  Others  Seafood  Snack Foods  \
#                 Item_category
# Item_Identifier DR               NaN     NaN      NaN          NaN
#                 FD             736.0     NaN     89.0       1989.0
#                 NC               NaN   280.0      NaN          NaN
#
# Item_Type                      Soft Drinks  Starchy Foods
#                 Item_category
# Item_Identifier DR                   726.0            NaN
#                 FD                     NaN          269.0
#                 NC                     NaN            NaN

# %% [markdown]
# Based on the above table we can create a new feature. Let’s call it Item_category.
#
# We will also change the values of Item_Fat_Content wherever Item_category is ‘NC’ because non-consumable items cannot have any fat content. We will also create a couple of more features — Outlet_Years (years of operation) and price_per_unit_wt (price per unit weight).
#
# -将NC类的Item_Fat_Content 改成Non-Edible，不是食物自然没有脂肪含量
#
# 创建新的特征：
#     - Outlet_Years (years of operation)
#     - price_per_unit_wt (price per unit weight).
#
# ### 4.3）运算并创建新的特征 Outlet_Years和 price_per_unit_wt

# %%
#假设今年是2013年，和课程假设一致
combine['Outlet_Years']=2013-combine['Outlet_Establishment_Year']
combine['price_per_unit_wt']=combine['Item_MRP']/combine['Item_Weight']

# %% [markdown]
# ### 4.4) 根据数据大小，分组标签
# Earlier in the Item_MRP vs Item_Outlet_Sales plot, we saw Item_MRP was spread across in 4 chunks. Now let’s assign a label to each of these chunks and use this label as a new variable.
#
# Item_MRP 份为4个区，我们这里也重新给他们分组

# %% [markdown]
# #### 方法- 用for 和if 语句
# c=[]
# for i in range(0,len(train['Item_MRP'])):
#     i = train['Item_MRP'][i]
#     if i< 69:
#         c.append("1st")
#     elif i< 136:
#         c.append("2nd")
#     elif i< 203:
#         c.append("3rd")
#     else:
#         c.append("4th")
#
# ####导入到表格中
# train['Item_MRP_clusters']=c

# %%
# 更方便的方法
bins=[0,69,136,203,300]
group=['1st','2nd','3rd','4th']
combine['Item_MRP_clusters']=pd.cut(combine['Item_MRP'],bins,labels=group)

# %% [markdown]
# ### 4.5）查看结果

# %%
combine.head(5)
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.017834
# 4           NCD19         8.93          Low Fat         0.009780
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# 2                       1999      Medium               Tier 1
# 3                       1998       Small               Tier 3
# 4                       1987        High               Tier 3
#
#          Outlet_Type  Item_Outlet_Sales   Item_Type_new Item_category  \
# 0  Supermarket Type1          3735.1380      perishable            FD
# 1  Supermarket Type2           443.4228  non_perishable            DR
# 2  Supermarket Type1          2097.2700      perishable            FD
# 3      Grocery Store           732.3800      perishable            FD
# 4  Supermarket Type1           994.7052  non_perishable            NC
#
#    Outlet_Years  price_per_unit_wt Item_MRP_clusters
# 0            14          26.861204               4th
# 1             4           8.153581               1st
# 2            14           8.092457               3rd
# 3            15           9.484115               3rd
# 4            26           6.031512               1st

# %% [markdown]
# ## 5）Encoding Categorical Variables
# - Label Encoding：
# simply means converting each category in a variable to a number. It is more suitable for ordinal variables — categorical variables with some order.
#     - Outlet_Size and Outlet_Location_Type
# - One Hot Encoding.
# each category of a categorical variable is converted into a new binary column (1/0).
# ==>

# %%
combine.dtypes
# Out:
# Item_Identifier                object
# Item_Weight                   float64
# Item_Fat_Content               object
# Item_Visibility               float64
# Item_Type                      object
# Item_MRP                      float64
# Outlet_Identifier              object
# Outlet_Establishment_Year       int64
# Outlet_Size                    object
# Outlet_Location_Type           object
# Outlet_Type                    object
# Item_Outlet_Sales             float64
# Item_Type_new                  object
# Item_category                  object
# Outlet_Years                    int64
# price_per_unit_wt             float64
# Item_MRP_clusters            category
# dtype: object

# %%
combine.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.017834
# 4           NCD19         8.93          Low Fat         0.009780
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# 2                       1999      Medium               Tier 1
# 3                       1998       Small               Tier 3
# 4                       1987        High               Tier 3
#
#          Outlet_Type  Item_Outlet_Sales   Item_Type_new Item_category  \
# 0  Supermarket Type1          3735.1380      perishable            FD
# 1  Supermarket Type2           443.4228  non_perishable            DR
# 2  Supermarket Type1          2097.2700      perishable            FD
# 3      Grocery Store           732.3800      perishable            FD
# 4  Supermarket Type1           994.7052  non_perishable            NC
#
#    Outlet_Years  price_per_unit_wt Item_MRP_clusters
# 0            14          26.861204               4th
# 1             4           8.153581               1st
# 2            14           8.092457               3rd
# 3            15           9.484115               3rd
# 4            26           6.031512               1st

# %% [markdown]
# Item_Identifier                object  - no
# Item_Weight                   float64
# Item_Fat_Content               object - laber *
# Item_Visibility               float64
# Item_Type                      object - drop
# Item_MRP                      float64
# Outlet_Identifier              object - dummy
# Outlet_Establishment_Year       int64 -drop
# Outlet_Size                    object  - laber *
# Outlet_Location_Type           object -laber *
# Outlet_Type                    object - dummy
# Item_Outlet_Sales             float64
# Item_Type_new                  object  - dummy
# Item_category                  object -dummy
# Outlet_Years                    int64
# price_per_unit_wt             float64
# Item_MRP_clusters            category -laber

# %% [markdown]
# ### 5.1） Label Encoding
# 将所有分类变量编码为数字。

# %%
from sklearn.preprocessing import LabelEncoder
LE = LabelEncoder()

#New variable for outlet
laber_features = ['Item_Fat_Content','Outlet_Size','Outlet_Location_Type','Item_Type_new','Item_MRP_clusters']
for i in laber_features:
    combine[i] = LE.fit_transform(combine[i])

# %%
'''
#查看特征类型
## Outlet_Size and Outlet_Location_Type
print(combine['Outlet_Size'].value_counts())
print(combine['Outlet_Location_Type'].value_counts())
'''
# Out:
# "\n#查看特征类型\n## Outlet_Size and Outlet_Location_Type\nprint(combine['Outlet_Size'].value_counts())\nprint(combine['Outlet_Location_Type'].value_counts())\n"

# %%
'''
#替换 ## 删除原文字标签，只保留数字标签
combine['Outlet_Size'].replace('Small',0,inplace=True)
combine['Outlet_Size'].replace('Medium',1,inplace=True)
combine['Outlet_Size'].replace('High',2,inplace=True)

combine['Outlet_Location_Type'].replace('Tier 3',0,inplace=True)
combine['Outlet_Location_Type'].replace('Tier 2',1,inplace=True)
combine['Outlet_Location_Type'].replace('Tier 1',2,inplace=True)
'''
# Out:
# "\n#替换 ## 删除原文字标签，只保留数字标签\ncombine['Outlet_Size'].replace('Small',0,inplace=True)\ncombine['Outlet_Size'].replace('Medium',1,inplace=True)\ncombine['Outlet_Size'].replace('High',2,inplace=True)\n\ncombine['Outlet_Location_Type'].replace('Tier 3',0,inplace=True)\ncombine['Outlet_Location_Type'].replace('Tier 2',1,inplace=True)\ncombine['Outlet_Location_Type'].replace('Tier 1',2,inplace=True)\n"

# %%
combine.head()
# Out:
#   Item_Identifier  Item_Weight  Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30                 0         0.016047
# 1           DRC01         5.92                 1         0.019278
# 2           FDN15        17.50                 0         0.016760
# 3           FDX07        19.20                 1         0.017834
# 4           NCD19         8.93                 0         0.009780
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year  Outlet_Size  Outlet_Location_Type  \
# 0                       1999            1                     0
# 1                       2009            1                     2
# 2                       1999            1                     0
# 3                       1998            2                     2
# 4                       1987            0                     2
#
#          Outlet_Type  Item_Outlet_Sales  Item_Type_new Item_category  \
# 0  Supermarket Type1          3735.1380              1            FD
# 1  Supermarket Type2           443.4228              0            DR
# 2  Supermarket Type1          2097.2700              1            FD
# 3      Grocery Store           732.3800              1            FD
# 4  Supermarket Type1           994.7052              0            NC
#
#    Outlet_Years  price_per_unit_wt  Item_MRP_clusters
# 0            14          26.861204                  3
# 1             4           8.153581                  0
# 2            14           8.092457                  2
# 3            15           9.484115                  2
# 4            26           6.031512                  0

# %% [markdown]
# # 独热编码

# %%
#One Hot Coding:
combine['Outlet'] = combine['Outlet_Identifier']
combine = pd.get_dummies(combine, columns=['Outlet','Outlet_Type','Item_category'])

# %%
'''
# 独热编码
combine0 = pd.get_dummies(combine['Outlet_Identifier'])
combine1 = pd.get_dummies(combine['Outlet_Type'])
combine2=pd.get_dummies(combine['Item_MRP_clusters'])
combine3=pd.get_dummies(combine['Item_category'])
combine=combine.join(combine0,how='outer')
combine=combine.join(combine1,how='outer')
combine=combine.join(combine2,how='outer')
combine=combine.join(combine3,how='outer')
'''
# Out:
# "\n# 独热编码\ncombine0 = pd.get_dummies(combine['Outlet_Identifier'])\ncombine1 = pd.get_dummies(combine['Outlet_Type'])\ncombine2=pd.get_dummies(combine['Item_MRP_clusters'])\ncombine3=pd.get_dummies(combine['Item_category'])\ncombine=combine.join(combine0,how='outer')\ncombine=combine.join(combine1,how='outer')\ncombine=combine.join(combine2,how='outer')\ncombine=combine.join(combine3,how='outer')\n"

# %%
#Drop the columns which have been converted to different types:
combine.drop(['Item_Type','Outlet_Establishment_Year'],axis=1,inplace=True)

# %%
combine.head().T
# Out:
#                                        0          1          2          3  \
# Item_Identifier                    FDA15      DRC01      FDN15      FDX07
# Item_Weight                          9.3       5.92       17.5       19.2
# Item_Fat_Content                       0          1          0          1
# Item_Visibility                0.0160473  0.0192782  0.0167601  0.0178343
# Item_MRP                         249.809    48.2692    141.618    182.095
# Outlet_Identifier                 OUT049     OUT018     OUT049     OUT010
# Outlet_Size                            1          1          1          2
# Outlet_Location_Type                   0          2          0          2
# Item_Outlet_Sales                3735.14    443.423    2097.27     732.38
# Item_Type_new                          1          0          1          1
# Outlet_Years                          14          4         14         15
# price_per_unit_wt                26.8612    8.15358    8.09246    9.48411
# Item_MRP_clusters                      3          0          2          2
# Outlet_OUT010                          0          0          0          1
# Outlet_OUT013                          0          0          0          0
# Outlet_OUT017                          0          0          0          0
# Outlet_OUT018                          0          1          0          0
# Outlet_OUT019                          0          0          0          0
# Outlet_OUT027                          0          0          0          0
# Outlet_OUT035                          0          0          0          0
# Outlet_OUT045                          0          0          0          0
# Outlet_OUT046                          0          0          0          0
# Outlet_OUT049                          1          0          1          0
# Outlet_Type_Grocery Store              0          0          0          1
# Outlet_Type_Supermarket Type1          1          0          1          0
# Outlet_Type_Supermarket Type2          0          1          0          0
# Outlet_Type_Supermarket Type3          0          0          0          0
# Item_category_DR                       0          1          0          0
# Item_category_FD                       1          0          1          1
# Item_category_NC                       0          0          0          0
#
#                                         4
# Item_Identifier                     NCD19
# Item_Weight                          8.93
# Item_Fat_Content                        0
# Item_Visibility                0.00977983
# Item_MRP                          53.8614
# Outlet_Identifier                  OUT013
# Outlet_Size                             0
# Outlet_Location_Type                    2
# Item_Outlet_Sales                 994.705
# Item_Type_new                           0
# Outlet_Years                           26
# price_per_unit_wt                 6.03151
# Item_MRP_clusters                       0
# Outlet_OUT010                           0
# Outlet_OUT013                           1
# Outlet_OUT017                           0
# Outlet_OUT018                           0
# Outlet_OUT019                           0
# Outlet_OUT027                           0
# Outlet_OUT035                           0
# Outlet_OUT045                           0
# Outlet_OUT046                           0
# Outlet_OUT049                           0
# Outlet_Type_Grocery Store               0
# Outlet_Type_Supermarket Type1           1
# Outlet_Type_Supermarket Type2           0
# Outlet_Type_Supermarket Type3           0
# Item_category_DR                        0
# Item_category_FD                        0
# Item_category_NC                        1

# %% [markdown]
# ## 数据预处理
# - Removing Skewness
# - Scaling numeric predictors
# - Correlated Variables

# %%
#Removing Skewness
combine['Item_Visibility']=np.log((combine['Item_Visibility']+1).astype('float'))
combine['Item_Visibility'].hist(bins=20)

# %% [markdown]
# 原来的图
# ![image.png](attachment:image.png)

# %%
combine['price_per_unit_wt'].hist(bins=20)

# %%
#Removing Skewness
combine['price_per_unit_wt']=np.log((combine['price_per_unit_wt']+1).astype('float'))
combine['price_per_unit_wt'].hist(bins=20)

# %% [markdown]
# ### Scaling numeric predictors：
# scale and center the numeric variables to make them have a mean of zero,
# standard deviation of one and scale of 0 to 1.
# Scaling and centering is required for linear regression models.'''
#
# 对数值变量进行标准化，使它们
# - Item_Weight
# -
# - price_per_unit_wt
# - Item_Visibility
# - Item_Outlet_Sales ( Y 不需要标准化）

# %%
combine=save

# %%
#Scaling numeric predictors
from sklearn.preprocessing import MinMaxScaler
combine['Item_Weight'] = MinMaxScaler().fit_transform(combine[['Item_Weight']])
combine['Item_MRP'] = MinMaxScaler().fit_transform(combine[['Item_MRP']])
combine['price_per_unit_wt'] = MinMaxScaler().fit_transform(combine[['price_per_unit_wt']])
combine['Item_Visibility'] = MinMaxScaler().fit_transform(combine[['Item_Visibility']])
combine['Outlet_Years'] = MinMaxScaler().fit_transform(combine[['Outlet_Years']])

# %%
combine.describe().T
# Out:
#                                  count         mean          std    min  \
# Item_Weight                    14204.0     0.490526     0.276970   0.00
# Item_Fat_Content               14204.0     0.353351     0.478027   0.00
# Item_Visibility                14204.0     0.223878     0.161574   0.00
# Item_MRP                       14204.0     0.465686     0.263529   0.00
# Outlet_Size                    14204.0     1.453605     0.683045   0.00
# Outlet_Location_Type           14204.0     1.112856     0.812755   0.00
# Item_Outlet_Sales               8523.0  2181.288914  1706.499616  33.29
# Item_Type_new                  14204.0     0.322163     0.467321   0.00
# Outlet_Years                   14204.0     0.465388     0.348819   0.00
# price_per_unit_wt              14204.0     0.499711     0.194915   0.00
# Item_MRP_clusters              14204.0     1.529921     0.947628   0.00
# Outlet_OUT010                  14204.0     0.065123     0.246751   0.00
# Outlet_OUT013                  14204.0     0.109335     0.312071   0.00
# Outlet_OUT017                  14204.0     0.108631     0.311187   0.00
# Outlet_OUT018                  14204.0     0.108843     0.311453   0.00
# Outlet_OUT019                  14204.0     0.061954     0.241081   0.00
# Outlet_OUT027                  14204.0     0.109758     0.312599   0.00
# Outlet_OUT035                  14204.0     0.109124     0.311806   0.00
# Outlet_OUT045                  14204.0     0.108983     0.311629   0.00
# Outlet_OUT046                  14204.0     0.109124     0.311806   0.00
# Outlet_OUT049                  14204.0     0.109124     0.311806   0.00
# Outlet_Type_Grocery Store      14204.0     0.127077     0.333071   0.00
# Outlet_Type_Supermarket Type1  14204.0     0.654323     0.475605   0.00
# Outlet_Type_Supermarket Type2  14204.0     0.108843     0.311453   0.00
# Outlet_Type_Supermarket Type3  14204.0     0.109758     0.312599   0.00
# Item_category_DR               14204.0     0.092720     0.290050   0.00
# Item_category_FD               14204.0     0.718178     0.449903   0.00
# Item_category_NC               14204.0     0.189102     0.391603   0.00
#
#                                       25%          50%          75%  \
# Item_Weight                      0.247395     0.479012     0.726109
# Item_Fat_Content                 0.000000     0.000000     1.000000
# Item_Visibility                  0.096654     0.185626     0.317216
# Item_MRP                         0.266224     0.470958     0.656055
# Outlet_Size                      1.000000     2.000000     2.000000
# Outlet_Location_Type             0.000000     1.000000     2.000000
# Item_Outlet_Sales              834.247400  1794.331000  3101.296400
# Item_Type_new                    0.000000     0.000000     1.000000
# Outlet_Years                     0.208333     0.416667     0.916667
# price_per_unit_wt                0.363263     0.506700     0.631302
# Item_MRP_clusters                1.000000     2.000000     2.000000
# Outlet_OUT010                    0.000000     0.000000     0.000000
# Outlet_OUT013                    0.000000     0.000000     0.000000
# Outlet_OUT017                    0.000000     0.000000     0.000000
# Outlet_OUT018                    0.000000     0.000000     0.000000
# Outlet_OUT019                    0.000000     0.000000     0.000000
# Outlet_OUT027                    0.000000     0.000000     0.000000
# Outlet_OUT035                    0.000000     0.000000     0.000000
# Outlet_OUT045                    0.000000     0.000000     0.000000
# Outlet_OUT046                    0.000000     0.000000     0.000000
# Outlet_OUT049                    0.000000     0.000000     0.000000
# Outlet_Type_Grocery Store        0.000000     0.000000     0.000000
# Outlet_Type_Supermarket Type1    0.000000     1.000000     1.000000
# Outlet_Type_Supermarket Type2    0.000000     0.000000     0.000000
# Outlet_Type_Supermarket Type3    0.000000     0.000000     0.000000
# Item_category_DR                 0.000000     0.000000     0.000000
# Item_category_FD                 0.000000     1.000000     1.000000
# Item_category_NC                 0.000000     0.000000     0.000000
#
#                                       max
# Item_Weight                        1.0000
# Item_Fat_Content                   1.0000
# Item_Visibility                    1.0000
# Item_MRP                           1.0000
# Outlet_Size                        2.0000
# Outlet_Location_Type               2.0000
# Item_Outlet_Sales              13086.9648
# Item_Type_new                      1.0000
# Outlet_Years                       1.0000
# price_per_unit_wt                  1.0000
# Item_MRP_clusters                  3.0000
# Outlet_OUT010                      1.0000
# Outlet_OUT013                      1.0000
# Outlet_OUT017                      1.0000
# Outlet_OUT018                      1.0000
# Outlet_OUT019                      1.0000
# Outlet_OUT027                      1.0000
# Outlet_OUT035                      1.0000
# Outlet_OUT045                      1.0000
# Outlet_OUT046                      1.0000
# Outlet_OUT049                      1.0000
# Outlet_Type_Grocery Store          1.0000
# Outlet_Type_Supermarket Type1      1.0000
# Outlet_Type_Supermarket Type2      1.0000
# Outlet_Type_Supermarket Type3      1.0000
# Item_category_DR                   1.0000
# Item_category_FD                   1.0000
# Item_category_NC                   1.0000

# %%
#不用标准化
'''
from sklearn.preprocessing import StandardScaler
ST['Item_Weight'] = StandardScaler().fit_transform(ST[['Item_Weight']])
ST['Item_MRP'] = StandardScaler().fit_transform(ST[['Item_MRP']])
ST['price_per_unit_wt'] = StandardScaler().fit_transform(ST[['price_per_unit_wt']])
ST['Item_Visibility'] = StandardScaler().fit_transform(ST[['Item_Visibility']])
ST['Outlet_Years'] = StandardScaler().fit_transform(ST[['Outlet_Years']])

#data = data.drop(['Time','Amount'],axis=1)
ST.describe().T
'''
# Out:
#                                  count          mean          std        min  \
# Item_Weight                    14204.0  2.669178e-16     1.000035  -1.771104
# Item_Fat_Content               14204.0  3.533512e-01     0.478027   0.000000
# Item_Visibility                14204.0 -5.907537e-17     1.000035  -1.385657
# Item_MRP                       14204.0 -1.115304e-16     1.000035  -1.767181
# Outlet_Size                    14204.0  1.453605e+00     0.683045   0.000000
# Outlet_Location_Type           14204.0  1.112856e+00     0.812755   0.000000
# Item_Outlet_Sales               8523.0  2.181289e+03  1706.499616  33.290000
# Item_Type_new                  14204.0  3.221628e-01     0.467321   0.000000
# Outlet_Years                   14204.0  6.759511e-17     1.000035  -1.334228
# price_per_unit_wt              14204.0  3.742430e-17     1.000035  -2.563827
# Item_MRP_clusters              14204.0  1.529921e+00     0.947628   0.000000
# Outlet_OUT010                  14204.0  6.512250e-02     0.246751   0.000000
# Outlet_OUT013                  14204.0  1.093354e-01     0.312071   0.000000
# Outlet_OUT017                  14204.0  1.086314e-01     0.311187   0.000000
# Outlet_OUT018                  14204.0  1.088426e-01     0.311453   0.000000
# Outlet_OUT019                  14204.0  6.195438e-02     0.241081   0.000000
# Outlet_OUT027                  14204.0  1.097578e-01     0.312599   0.000000
# Outlet_OUT035                  14204.0  1.091242e-01     0.311806   0.000000
# Outlet_OUT045                  14204.0  1.089834e-01     0.311629   0.000000
# Outlet_OUT046                  14204.0  1.091242e-01     0.311806   0.000000
# Outlet_OUT049                  14204.0  1.091242e-01     0.311806   0.000000
# Outlet_Type_Grocery Store      14204.0  1.270769e-01     0.333071   0.000000
# Outlet_Type_Supermarket Type1  14204.0  6.543227e-01     0.475605   0.000000
# Outlet_Type_Supermarket Type2  14204.0  1.088426e-01     0.311453   0.000000
# Outlet_Type_Supermarket Type3  14204.0  1.097578e-01     0.312599   0.000000
# Item_category_DR               14204.0  9.272036e-02     0.290050   0.000000
# Item_category_FD               14204.0  7.181780e-01     0.449903   0.000000
# Item_category_NC               14204.0  1.891017e-01     0.391603   0.000000
#
#                                       25%          50%          75%  \
# Item_Weight                     -0.877853    -0.041573     0.850602
# Item_Fat_Content                 0.000000     0.000000     1.000000
# Item_Visibility                 -0.787433    -0.236752     0.577702
# Item_MRP                        -0.756917     0.020005     0.722410
# Outlet_Size                      1.000000     2.000000     2.000000
# Outlet_Location_Type             0.000000     1.000000     2.000000
# Item_Outlet_Sales              834.247400  1794.331000  3101.296400
# Item_Type_new                    0.000000     0.000000     1.000000
# Outlet_Years                    -0.736955    -0.139681     1.293777
# price_per_unit_wt               -0.700058     0.035861     0.675144
# Item_MRP_clusters                1.000000     2.000000     2.000000
# Outlet_OUT010                    0.000000     0.000000     0.000000
# Outlet_OUT013                    0.000000     0.000000     0.000000
# Outlet_OUT017                    0.000000     0.000000     0.000000
# Outlet_OUT018                    0.000000     0.000000     0.000000
# Outlet_OUT019                    0.000000     0.000000     0.000000
# Outlet_OUT027                    0.000000     0.000000     0.000000
# Outlet_OUT035                    0.000000     0.000000     0.000000
# Outlet_OUT045                    0.000000     0.000000     0.000000
# Outlet_OUT046                    0.000000     0.000000     0.000000
# Outlet_OUT049                    0.000000     0.000000     0.000000
# Outlet_Type_Grocery Store        0.000000     0.000000     0.000000
# Outlet_Type_Supermarket Type1    0.000000     1.000000     1.000000
# Outlet_Type_Supermarket Type2    0.000000     0.000000     0.000000
# Outlet_Type_Supermarket Type3    0.000000     0.000000     0.000000
# Item_category_DR                 0.000000     0.000000     0.000000
# Item_category_FD                 0.000000     1.000000     1.000000
# Item_category_NC                 0.000000     0.000000     0.000000
#
#                                         max
# Item_Weight                        1.839519
# Item_Fat_Content                   1.000000
# Item_Visibility                    4.803689
# Item_MRP                           2.027606
# Outlet_Size                        2.000000
# Outlet_Location_Type               2.000000
# Item_Outlet_Sales              13086.964800
# Item_Type_new                      1.000000
# Outlet_Years                       1.532686
# price_per_unit_wt                  2.566798
# Item_MRP_clusters                  3.000000
# Outlet_OUT010                      1.000000
# Outlet_OUT013                      1.000000
# Outlet_OUT017                      1.000000
# Outlet_OUT018                      1.000000
# Outlet_OUT019                      1.000000
# Outlet_OUT027                      1.000000
# Outlet_OUT035                      1.000000
# Outlet_OUT045                      1.000000
# Outlet_OUT046                      1.000000
# Outlet_OUT049                      1.000000
# Outlet_Type_Grocery Store          1.000000
# Outlet_Type_Supermarket Type1      1.000000
# Outlet_Type_Supermarket Type2      1.000000
# Outlet_Type_Supermarket Type3      1.000000
# Item_category_DR                   1.000000
# Item_category_FD                   1.000000
# Item_category_NC                   1.000000

# %%
corr = combine.corr()
mask = np.zeros_like(corr)
mask[np.triu_indices_from(mask)] = True
with sns.axes_style("white"):
    f, ax = plt.subplots(figsize=(10, 7))
    ax = sns.heatmap(corr, mask=mask, vmax=.3, square=True)

# %% [markdown]
# ### Splitting the combined data combi back to train and test set.

# %%
#Divide into test and train:
train = combine.loc[combine['Item_Outlet_Sales'].notnull()]
test = combine.loc[combine['Item_Outlet_Sales'].isnull()]

# %%
#删掉test 中多余的列
test.drop(['Item_Outlet_Sales'],axis=1,inplace=True)


#导出数据
train.to_csv("train_modified.csv",index=False)
test.to_csv("test_modified.csv",index=False)
# Out:
# /Users/mac/opt/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py:3997: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
print(train.shape,test.shape)
# Out:
# (8523, 30) (5681, 29)

# %%
combine.dtypes
# Out:
# Item_Identifier                   object
# Item_Weight                      float64
# Item_Fat_Content                   int64
# Item_Visibility                  float64
# Item_MRP                         float64
# Outlet_Identifier                 object
# Outlet_Size                        int64
# Outlet_Location_Type               int64
# Item_Outlet_Sales                float64
# Item_Type_new                      int64
# Outlet_Years                     float64
# price_per_unit_wt                float64
# Item_MRP_clusters                  int64
# Outlet_OUT010                      uint8
# Outlet_OUT013                      uint8
# Outlet_OUT017                      uint8
# Outlet_OUT018                      uint8
# Outlet_OUT019                      uint8
# Outlet_OUT027                      uint8
# Outlet_OUT035                      uint8
# Outlet_OUT045                      uint8
# Outlet_OUT046                      uint8
# Outlet_OUT049                      uint8
# Outlet_Type_Grocery Store          uint8
# Outlet_Type_Supermarket Type1      uint8
# Outlet_Type_Supermarket Type2      uint8
# Outlet_Type_Supermarket Type3      uint8
# Item_category_DR                   uint8
# Item_category_FD                   uint8
# Item_category_NC                   uint8
# dtype: object

# %% [markdown]
# from sklearn.preprocessing import StandardScaler
#
# data['normAmount'] = StandardScaler().fit_transform(data['Amount'].values.reshape(-1, 1))
# data = data.drop(['Time','Amount'],axis=1)
# data.head()

# %% [markdown]
# ![1549264816838.jpg.png](attachment:1549264816838.jpg.png)
# The correlation plot above shows correlation between all the possible pairs of variables in out data. The correlation between any two variables is represented by a pie. A blueish pie indicates positive correlation and reddish pie indicates negative correlation. The magnitude of the correlation is denoted by the area covered by the pie.
#
# Variables price_per_unit_wt and Item_Weight are highly correlated as the former one was created from the latter. Similarly price_per_unit_wt and Item_MRP are highly correlated for the same reason.

# %% [markdown]
# # Model Building
# - Linear Regression
# - Lasso Regression
# - Ridge Regression
# - RandomForest
# - XGBoost
#
# ### Evaluation Metrics for Regression
#
# Mean Absolute Error (MAE) is the mean of the absolute value of the errors:
# ![image.png](attachment:image.png)

# %% [markdown]
# Mean Squared Error (MSE) is the mean of the squared errors:
#
#
# ![image.png](attachment:image.png)

# %% [markdown]
# Root Mean Squared Error (RMSE) is the square root of the mean of the squared errors:
# ![image.png](attachment:image.png)

# %% [markdown]
# At the competition’s page, it has been mentioned that our submission data would be evaluated based on the RMSE score. Hence, we will use RMSE as our evaluation metric.
#
# To know more about evaluation metrics, read this article.

# %% [markdown]
# Regularised regression models can handle the correlated independent variables well and helps in overcoming overfitting. Ridge penalty shrinks the coefficients of correlated predictors towards each other, while the Lasso tends to pick one of a pair of correlated features and discard the other. The tuning parameter lambda controls the strength of the penalty.
# - Lasso Regression
# - Ridge Regression
#
# https://courses.analyticsvidhya.com/courses/take/big-mart-sales-prediction-using-r/texts/6120189-regularized-linear-regression
#
# RandomForest is a tree based bootstrapping algorithm wherein a certain number of weak learners (decision trees) are combined to make a powerful prediction model. For every individual learner, a random sample of rows and a few randomly chosen variables are used to build a decision tree model. Final prediction can be a function of all the predictions made by the individual learners. In case of a regression problem, the final prediction can be mean of all the predictions. For detailed explanation visit this article.
#
#
# XGBoost is a fast and efficient algorithm and has been used to by the winners of many data science competitions. It’s a boosting algorithm and you may refer this article to know more about boosting. XGBoost works only with numeric variables and we have already replaced the categorical variables with numeric variables. There are many tuning parameters in XGBoost which can be broadly classified into General Parameters, Booster Parameters and Task Parameters.
#
# General parameters refer to which booster we are using to do boosting. The commonly used are tree or linear model
# Booster parameters depend on which booster you have chosen
# Learning Task parameters that decide on the learning scenario, for example, regression tasks may use different parameters with ranking tasks.
# Let’s have a look at the parameters that we are going to use in our model.
#
# eta: It is also known as the learning rate or the shrinkage factor. It actually shrinks the feature weights to make the boosting process more conservative. The range is 0 to 1. Low eta value means the model is more robust to overfitting.
# gamma: The range is 0 to ∞. Larger the gamma more conservative the algorithm is.
# max_depth: We can specify maximum depth of a tree using this parameter.
# subsample: It is the proportion of rows that the model will randomly select to grow trees.
# colsample_bytree: It is the ratio of variables randomly chosen to build each tree in the model.

# %% [markdown]
# After trying and testing 5 different algorithms, the best score on the public leaderboard has been achieved by XGBoost (1154.70), followed by RandomForest (1157.25). However, there are still a plenty of things that we can try to further improve our predictions.
#
#
# What else can be tried…
#
# There are still quite a many things that can be tried to improve our models’ predictions. We can create and add more variables, try different models with different subset of features, etc. Some of the ideas based on our EDA are listed below:
#
# We can transform the target variable to reduce its skewness.
#
# We can also make independent vs independent variable visualizations to discover some more patterns.
#
# We found out four groups of Item_MRP in EDA. We can create a separate model for each of these groups and then combine the predictions.
#
# Based on the violin plots, we can group the categories of the categorical variables which are quite similar in shape and size.
#
# We can train the XGBoost model using grid search as done in the case of RandomForest.
#
# We can even use different algorithms such as LightGBM or neural network based models.
#
# Model ensembling can also be of great help in improving the model’s performance.
#
#
# Listed below are some useful links:
#
# Exploratory Data Analysis
#
# Ensemble Modeling in R
#
# Light GBM vs XGBoost
#
# I hope this tutorial was helpful for you in understanding how a machine learning competition is approached and what are the steps one should go through to build a robust model. So, do replicate this analysis and let us know if you face any issues.

# %%
X=train.drop('Item_Outlet_Sales',1)
y=train.Item_Outlet_Sales

# %%
from sklearn.model_selection import train_test_split
#import LogisticReression and accuracy_score from sklearn and fit the lofistic regression model
x_train, x_cv, y_train, y_cv = train_test_split(X,y, test_size =0.3)

# %%
from sklearn.linear_model import LogisticRegression 
from sklearn.metrics import accuracy_score

model = LogisticRegression() 
model.fit(x_train, y_train)

LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True, intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=1, penalty='l2', random_state=1, solver='liblinear', tol=0.0001, verbose=0, warm_start=False)
